# %% [markdown]
# <a href="https://colab.research.google.com/github/Shinramen-5/basics/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is a comment and is not read by python
print('Hello! This is the print function. Python will print this line below')
# Write a basic for loop.
for i in range(5):
    # Multiply the value of i by two and assign it to a varible
    temp_variable = 2 * i
    # Print the value of the temp variable.
    print(temp_variable)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() # This line sets the style through seaborn to make the plot look nicer.
# Plot one of Griffin's favourite functions.
x = np.linspace(-np.pi, np.pi , 500)
y = np.sin(2 * np.sin(2 * np.sin(2 * x)))
# generate the plot.
plt.plot(x,y)
# Out:
# Hello! This is the print function. Python will print this line below
# 0
# 2
# 4
# 6
# 8
